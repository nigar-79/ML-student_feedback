# %%
import numpy as np
import pandas as pd

# %%
student_feedback=pd.read_csv('./student_feedback.csv')

# %%
student_feedback.head()
# Out:
#    Unnamed: 0  Student ID  Well versed with the subject  \
# 0           0         340                             5
# 1           1         253                             6
# 2           2         680                             7
# 3           3         806                             9
# 4           4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# ...

# %%
student_feedback.shape
# Out:
# (1001, 10)

# %%
student_feedback.isnull().sum()
# Out:
# Unnamed: 0                                              0
# Student ID                                              0
# Well versed with the subject                            0
# Explains concepts in an understandable way              0
# Use of presentations                                    0
# Degree of difficulty of assignments                     0
# Solves doubts willingly                                 0
# Structuring of the course                               0
# Provides support for students going above and beyond    0
# Course recommendation based on relevance                0
# dtype: int64

# %%
plt.figure();
student_feedback.iloc[5].plot(kind="bar");

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(17,7))
plt.subplot(2,2,1)
sns.countplot(x='Explains concepts in an understandable way', hue='Well versed with the subject',data=student_feedback)
# Out:
# <AxesSubplot:xlabel='Explains concepts in an understandable way', ylabel='count'>

# %%
sns.pairplot(student_feedback, height=2)
